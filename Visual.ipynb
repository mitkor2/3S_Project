# %%
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt

# %%
data = read_csv('Logbook.csv')

# %%
data.dropna(axis=1, how='all',inplace=True)

# %%
data.head()
# Out:
#      H1     W1    H2     W2    H3     W3    H4     W4    H5     W5    H6  \
# 0  42.5  154.0  42.5  154.0  42.5  154.0  42.5  154.0  42.5  154.0  42.5
# 1  42.5  154.0  42.5  154.0  42.5  154.0  42.5  154.0  42.5  154.0  42.5
# 2  42.5  154.0  42.5  154.0  42.5  154.0  42.5  154.0  42.5  154.0  42.5
# 3  42.5  154.0  42.5  154.0  42.5  154.0  42.5  154.0  42.5  154.0  42.5
# 4  42.5  154.0  42.5  154.0  42.5  154.0  42.5  154.0  42.5  154.0  42.5
#
#       W6    TO    T1    T2    T3    T4    T5    T6
# 0  154.0  24.6  24.6  24.6  24.6  24.6  24.6  24.6
# 1  154.0  24.6  24.6  24.6  24.6  24.6  24.6  24.6
# 2  154.0  24.6  24.6  24.6  24.6  24.6  24.6  24.6
# 3  154.0  24.6  24.6  24.6  24.6  24.6  24.6  24.6
# 4  154.0  24.6  24.6  24.6  24.6  24.6  24.6  24.6

# %%
print(type(data.H1))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data.hist(bins=20, figsize=(25,32), grid=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000029977F9EB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978511668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978556BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978D01198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000029978D2F748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978D5DCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978D972E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978DC68D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000029978DC6908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978E34438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978E679E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978E98F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000029978ED4588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978F05B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978F44128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978F766D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000029978FA7C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029978FE7278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029979018828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029979049DD8>]],
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=3, nrows=7, figsize=(18, 32))
index = 0
axs = axs.flatten()
for k, v in data.items():
    sns.distplot(v, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
corr = data.corr().abs()
plt.figure(figsize=(16, 12))
sns.heatmap(corr, square=True, annot=True, cmap='Greens')
plt.tight_layout()
